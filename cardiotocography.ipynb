# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_excel('CTG.xls',sheet_name=1)

# %%
df['Unnamed: 9'].isnull().sum()

# %%
print(df.columns.tolist())

# %%
empty_cols = ['Unnamed: 9', 'Unnamed: 42', 'Unnamed: 44']  # Note: also need column 45
print(f"Empty columns to drop: {empty_cols}")

# Drop empty columns and rows that are all NaN
df = df.drop(columns=empty_cols)  # Pass string names, not Series objects

# The last row contains summary statistics - remove it
print(f"\nLast row values: {df.iloc[-1, :5].values}")
df = df.iloc[:-1]  # Remove summary row

print(f"Shape after cleaning: {df.shape}")
